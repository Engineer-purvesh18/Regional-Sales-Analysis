# %% [markdown]
# REGIONAL SALES ANALYSIS

# %%
# Importing required libraries and packages 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing data
sheets = pd.read_excel("Regional Sales Dataset.xlsx", sheet_name=None)

# %%
# Assigning names and crating diffferent data frames form sheets in the xlsl file

df_sales = sheets['Sales Orders']
df_customers = sheets['Customers']
df_regions = sheets['Regions']
df_state_Regions = sheets['State Regions']
df_products = sheets['Products']
df_2017_budget = sheets['2017 Budgets']

# %%
df_2017_budget.head(5)
# Out:
#   Product Name  2017 Budgets
# 0    Product 1   3016489.209
# 1    Product 2   3050087.565
# 2    Product 3   2642352.432
# 3    Product 4   2885560.824
# 4    Product 5   3925424.542
